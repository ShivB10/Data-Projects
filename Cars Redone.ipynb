# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as ny

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #adjusting the configuration of the plots we will create

#reading in the data


df = pd.read_csv(r'/Users/ShivenB/Downloads/Cars Data.csv')

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.dropna()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df['EngineSize'] = df['EngineSize'].astype('int64')
df['Cylinders'] = df['Cylinders'].astype('int64')
df['Horsepower'] = df['Horsepower'].astype('int64')
df['MPG_City'] = df['MPG_City'].astype('int64')
df['MPG_Highway'] = df['MPG_Highway'].astype('int64')
df['Weight'] = df['Weight'].astype('int64')
df['Wheelbase'] = df['Wheelbase'].astype('int64')
df['Length'] = df['Length'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/569682277.py in <module>
# ----> 1 df['EngineSize'] = df['EngineSize'].astype('int64')
#       2 df['Cylinders'] = df['Cylinders'].astype('int64')
#       3 df['Horsepower'] = df['Horsepower'].astype('int64')
#       4 df['MPG_City'] = df['MPG_City'].astype('int64')
#       5 df['MPG_Highway'] = df['MPG_Highway'].astype('int64')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ...

# %%
df['Weight'] = df['Weight'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/454856822.py in <module>
# ----> 1 df['Weight'] = df['Weight'].astype(int)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
# ...

# %%
df['Weight'] = df['Weight'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/3061566142.py in <module>
# ----> 1 df['Weight'] = df['Weight'].astype('int64')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
# ...

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df['EngineSize'] = df['EngineSize'].astype('int64')
df['Cylinders'] = df['Cylinders'].astype('int64')
df['Horsepower'] = df['Horsepower'].astype('int64')
df['MPG_City'] = df['MPG_City'].astype('int64')
df['MPG_Highway'] = df['MPG_Highway'].astype('int64')
df['Weight'] = df['Weight'].astype('int64')
df['Wheelbase'] = df['Wheelbase'].astype('int64')
df['Length'] = df['Length'].astype('int64')

# %%
df.dtypes
# Out:
# Make           object
# Model          object
# Type           object
# Origin         object
# DriveTrain     object
# MSRP           object
# Invoice        object
# EngineSize      int64
# Cylinders       int64
# Horsepower      int64
# MPG_City        int64
# MPG_Highway     int64
# Weight          int64
# Wheelbase       int64
# Length          int64
# dtype: object

# %%
#Convert MSRP to int
df['MSRP'] = df['MSRP'].str.replace(',', '')
df['MSRP'] = df['MSRP'].str.replace('$', '')
df['MSRP'] = df['MSRP'].astype('int64')

#Convert Invoice to int
df['Invoice'] = df['Invoice'].str.replace(',', '')
df['Invoice'] = df['Invoice'].str.replace('$', '')
df['Invoice'] = df['Invoice'].astype('int64')
# Out:
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/660943383.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['MSRP'] = df['MSRP'].str.replace('$', '')
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/660943383.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Invoice'] = df['Invoice'].str.replace('$', '')

# %%
df.dtypes
# Out:
# Make           object
# Model          object
# Type           object
# Origin         object
# DriveTrain     object
# MSRP            int64
# Invoice         int64
# EngineSize      int64
# Cylinders       int64
# Horsepower      int64
# MPG_City        int64
# MPG_Highway     int64
# Weight          int64
# Wheelbase       int64
# Length          int64
# dtype: object

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain   MSRP  Invoice  EngineSize  \
# 0  Acura             MDX    SUV   Asia        All  36945    33337           3
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820    21761           2
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990    24647           2
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195    30299           3
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755    39014           3
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0          6         265        17           23    4451        106     189
# 1          4         200        24           31    2778        101     172
# 2          4         200        22           29    3230        105     183
# 3          6         270        20           28    3575        108     186
# 4          6         225        18           24    3880        115     197

# %%
df.corr()
# Out:
#                  MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# MSRP         1.000000  0.999132    0.575790   0.649742    0.827296 -0.475916
# Invoice      0.999132  1.000000    0.569616   0.645226    0.824079 -0.471304
# EngineSize   0.575790  0.569616    1.000000   0.878011    0.780515 -0.705092
# Cylinders    0.649742  0.645226    0.878011   1.000000    0.810341 -0.684402
# Horsepower   0.827296  0.824079    0.780515   0.810341    1.000000 -0.677034
# MPG_City    -0.475916 -0.471304   -0.705092  -0.684402   -0.677034  1.000000
# MPG_Highway -0.440523 -0.435452   -0.712689  -0.676100   -0.647425  0.940993
# Weight       0.447987  0.441916    0.786163   0.742209    0.631758 -0.740418
# Wheelbase    0.151665  0.148003    0.617257   0.546730    0.387561 -0.508029
# Length       0.171060  0.165645    0.598369   0.547783    0.382386 -0.504184
#
#              MPG_Highway    Weight  Wheelbase    Length
# MSRP           -0.440523  0.447987   0.151665  0.171060
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Heatmap')

plt.xlabel("Car Features")

plt.ylabel("Car Features")

plt.show()

# %%
#import libary

from sklearn import linear_model

# %%
#assigning the strong correlation values to X and Y

X = df[['Horsepower', 'EngineSize', 'Cylinders']]
y = df['MSRP']

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.show(regr.fit(X, y))

# %%
sns.regplot(x, y, data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/330828710.py in <module>
# ----> 1 sns.regplot(x, y, data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
#
# NameError: name 'x' is not defined

# %%
sns.regplot(X, y, data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# /Users/ShivenB/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/1073814609.py in <module>
# ----> 1 sns.regplot(X, y, data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# plot Horsepower vs MSRP revenue using seaborn

sns.regplot(x='Horsepower', y='MSRP', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Horsepower', ylabel='MSRP'>

# %%
# plot Cylinder Count vs MSRP revenue using seaborn

sns.regplot(x='Cylinders', y='MSRP', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='MSRP'>

# %%
# plot EngineSize  vs MSRP revenue using seaborn

sns.regplot(x='EngineSize', y='MSRP', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='EngineSize', ylabel='MSRP'>

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
        
df_numerized.head()= df
# Out:
#   File "/var/folders/_h/ls2v2rwd6blc_2bh3jxz_qt40000gp/T/ipykernel_32584/650472982.py", line 9
#     df_numerized.head()= df
#     ^
# SyntaxError: cannot assign to function call

# %%
sns.boxplot(data=df, x="EngineSize", y="MSRP")
# Out:
# <AxesSubplot:xlabel='EngineSize', ylabel='MSRP'>
